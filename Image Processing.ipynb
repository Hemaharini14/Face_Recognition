# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
import os
sharukan=os.listdir("D:/dataset/Ar rahman")

# %%
arr=os.listdir("D:/dataset/Sharukhan")

# %%
ir=os.listdir("D:/dataset/Irwin")

# %%
limit = 10
sharukan_images = [None]*limit
j=0

for i in sharukan:
    if(j<limit):
        sharukan_images[j] = imread("D:/dataset/Sharukhan/"+i)
        j+=1
    else:
        break

# %%
limit = 10
arr_images =[None]*limit
j=0


for i in arr:
    if(j<limit):
        arr_images[j]=imread("D:/dataset/Ar rahman/"+i)
        j+=1
    else:
        break

# %%
limit = 10
ir_images =[None]*limit
j=0


for i in ir:
    if(j<limit):
        ir_images[j]=imread("D:/dataset/Irwin/"+i)
        j+=1
    else:
        break

# %%
imshow(sharukan_images[5])

# %%
imshow(arr_images[7])

# %%
imshow(ir_images[3])

# %%
sharukan_gray = [None]*limit
j=0
for i in sharukan:
    if(j<limit):
        sharukan_gray[j]=rgb2gray(sharukan_images[j])
        j+=1
    else:
        break

# %%
arr_gray = [None]*limit
j=0
for i in arr:
    if(j<limit):
        arr_gray[j]=rgb2gray(arr_images[j])
        j+=1
    else:
        break

# %%
ir_gray = [None]*limit
j=0
for i in ir:
    if(j<limit):
        ir_gray[j]=rgb2gray(ir_images[j])
        j+=1
    else:
        break

# %%
imshow(sharukan_gray[4])

# %%
imshow(arr_gray[1])

# %%
imshow(ir_gray[1])

# %%
sharukan_gray[8].shape
# Out:
# (1280, 1280)

# %%
arr_gray[4].shape
# Out:
# (168, 300)

# %%
ir_gray[4].shape
# Out:
# (853, 1280)

# %%
for j in range(10):
    s=sharukan_gray[j]
    sharukan_gray[j]=resize(s,(512,512))

# %%
for j in range(10):
    a=arr_gray[j]
    arr_gray[j]=resize(a,(512,512))

# %%
for j in range(10):
    i=ir_gray[j]
    ir_gray[j]=resize(i,(512,512))

# %%
imshow(sharukan_gray[7])

# %%
imshow(arr_gray[8])

# %%
imshow(ir_gray[5])

# %%
len_of_images_sharukan=len(sharukan_gray)
len_of_images_sharukan
# Out:
# 10

# %%
len_of_images_arr=len(arr_gray)
len_of_images_arr
# Out:
# 10

# %%
len_of_images_ir=len(ir_gray)
len_of_images_ir
# Out:
# 10

# %%
image_size_sharukan=sharukan_gray[1].shape

# %%
image_size_arr=arr_gray[1].shape

# %%
image_size_ir=ir_gray[1].shape

# %%
flatten_size_sharukan = image_size_sharukan[0]*image_size_sharukan[1]
flatten_size_sharukan
# Out:
# 262144

# %%
flatten_size_arr = image_size_arr[0]*image_size_arr[1]
flatten_size_arr
# Out:
# 262144

# %%
flatten_size_ir = image_size_ir[0]*image_size_ir[1]
flatten_size_ir
# Out:
# 262144

# %%
for i in range(len_of_images_sharukan):
    sharukan_gray[i]=np.ndarray.flatten(sharukan_gray[i].reshape(flatten_size_sharukan,1))

# %%
sharukan_gray=np.dstack(sharukan_gray)

# %%
sharukan_gray=np.rollaxis(sharukan_gray,axis=2,start=0)
sharukan_gray.shape
# Out:
# (10, 1, 262144)

# %%
sharukan_gray=sharukan_gray.reshape(len_of_images_sharukan,flatten_size_arr)
sharukan_gray.shape
# Out:
# (10, 262144)

# %%
sharukan_data=pd.DataFrame(sharukan_gray)

# %%
sharukan_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.770823  0.770823  0.770823  0.770823  0.770823  0.770822  0.770639
# 1  0.832705  0.832705  0.832705  0.832705  0.832705  0.832705  0.831879
# 2  0.050980  0.050980  0.050980  0.050980  0.050980  0.050980  0.050980
# 3  0.648926  0.648913  0.646850  0.648232  0.648926  0.648926  0.648926
# 4  0.889675  0.889675  0.889675  0.889675  0.889675  0.889675  0.887224
# 5  0.848459  0.842223  0.851072  0.848343  0.848885  0.843758  0.852798
# 6  0.132778  0.131386  0.131103  0.125987  0.123453  0.124461  0.127451
# 7  0.253213  0.250377  0.249941  0.254260  0.254248  0.253923  0.254211
# 8  0.991722  0.995394  0.995531  0.996881  0.997687  0.997613  0.998637
# 9  0.454219  0.454248  0.454295  0.454340  0.454340  0.454108  0.454540
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.770081  0.769975  0.769975  ...  0.750287  0.750244  0.750244  0.750244
# ...

# %%
sharukan_data["Label"]="King Sharukan"
sharukan_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.770823  0.770823  0.770823  0.770823  0.770823  0.770822  0.770639
# 1  0.832705  0.832705  0.832705  0.832705  0.832705  0.832705  0.831879
# 2  0.050980  0.050980  0.050980  0.050980  0.050980  0.050980  0.050980
# 3  0.648926  0.648913  0.646850  0.648232  0.648926  0.648926  0.648926
# 4  0.889675  0.889675  0.889675  0.889675  0.889675  0.889675  0.887224
# 5  0.848459  0.842223  0.851072  0.848343  0.848885  0.843758  0.852798
# 6  0.132778  0.131386  0.131103  0.125987  0.123453  0.124461  0.127451
# 7  0.253213  0.250377  0.249941  0.254260  0.254248  0.253923  0.254211
# 8  0.991722  0.995394  0.995531  0.996881  0.997687  0.997613  0.998637
# 9  0.454219  0.454248  0.454295  0.454340  0.454340  0.454108  0.454540
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.770081  0.769975  0.769975  ...  0.750244  0.750244  0.750244  0.750244
# ...

# %%
for i in range(len_of_images_arr):
    arr_gray[i]=np.ndarray.flatten(arr_gray[i].reshape(flatten_size_arr,1))

# %%
arr_gray=np.dstack(arr_gray)

# %%
arr_gray=np.rollaxis(arr_gray,axis=2,start=0)
arr_gray.shape
# Out:
# (10, 1, 262144)

# %%
arr_gray=arr_gray.reshape(len_of_images_arr,flatten_size_arr)
arr_gray.shape
# Out:
# (10, 262144)

# %%
arr_data=pd.DataFrame(arr_gray)

# %%
arr_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0

# Out:
#            0         1         2         3         4         5         6  \
# 0   0.777580  0.772503  0.771425  0.762717  0.763537  0.770465  0.780188
# 1   0.821189  0.821189  0.821646  0.824967  0.825110  0.826163  0.829032
# 2   0.725379  0.716721  0.739780  0.749924  0.746856  0.760181  0.762270
# 3   0.770823  0.770823  0.770823  0.770823  0.770823  0.770822  0.770639
# 4   0.495754  0.495984  0.505903  0.516882  0.528785  0.538474  0.546409
# 5   0.682718  0.679323  0.668332  0.663204  0.667685  0.677091  0.685544
# 6   0.050980  0.050980  0.050980  0.050980  0.050980  0.050980  0.050980
# 7   0.756587  0.753889  0.746592  0.749353  0.761510  0.772715  0.774197
# 8   0.425081  0.424596  0.426127  0.427630  0.428006  0.428382  0.430688
# 9   0.685549  0.692606  0.700757  0.708121  0.701793  0.695862  0.689707
# 10  0.454219  0.454248  0.454295  0.454340  0.454340  0.454108  0.454540
# 11  0.728741  0.735217  0.738809  0.744376  0.750909  0.757433  0.761887
# ...

# %%
x = data.values[:,:-1]

# %%
y = data.values[:,-1]

# %%
x
# Out:
# array([[0.777579992108207, 0.7725030411831192, 0.7714253579766663, ...,
#         0.46052418321388644, 0.4622279086439668, 0.45753356451678295],
#        [0.8211886274509804, 0.8211886274509804, 0.8216462976253734, ...,
#         0.8203619056372549, 0.8086611707320867, 0.789187365585028],
#        [0.7253788053424971, 0.7167212511019164, 0.7397797802211075, ...,
#         0.25792745852827026, 0.2583758273169202, 0.26630360558500743],
#        ...,
#        [0.889675294117647, 0.889675294117647, 0.889675294117647, ...,
#         0.047896568627451154, 0.05126666666666679, 0.05206323529411803],
#        [0.029423137254901963, 0.029423137254901963, 0.029423137254901963,
#         ..., 0.043137254901960784, 0.043137254901960784,
#         0.043137254901960784],
#        [0.431018791994581, 0.4311000118839039, 0.43137689787023215, ...,
#         0.6522570833333333, 0.6522570833333333, 0.6522570833333334]],
#       dtype=object)

# %%
y
# Out:
# array(['Irwin Pascal', 'Irwin Pascal', 'Irwin Pascal', 'King Sharukan',
#        'Ar Rahaman', 'Irwin Pascal', 'King Sharukan', 'Irwin Pascal',
#        'Ar Rahaman', 'Irwin Pascal', 'King Sharukan', 'Irwin Pascal',
#        'King Sharukan', 'Ar Rahaman', 'King Sharukan', 'Irwin Pascal',
#        'Ar Rahaman', 'Irwin Pascal', 'Ar Rahaman', 'Ar Rahaman',
#        'Irwin Pascal', 'Ar Rahaman', 'King Sharukan', 'Ar Rahaman',
#        'King Sharukan', 'King Sharukan', 'King Sharukan', 'King Sharukan',
#        'Ar Rahaman', 'Ar Rahaman'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Irwin Pascal', 'King Sharukan', 'Ar Rahaman', 'Ar Rahaman',
#        'Ar Rahaman', 'King Sharukan'], dtype=object)

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.5

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1, 0, 1],
#        [0, 1, 0],
#        [2, 0, 1]], dtype=int64)
